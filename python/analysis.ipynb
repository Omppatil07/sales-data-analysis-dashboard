# %%
# import pandas and CSV files

# %%
import pandas as pd

sales = pd.read_csv("sales.csv")
customers = pd.read_csv("customers.csv")
products = pd.read_csv("products.csv")

sales
# Out:
#      order_ID  order_date    sales   profit  customer_id  product_id
# 0        9091  2010-11-11   605.77   129.33            1           1
# 1       36355  2009-02-12   129.50    65.49            2           2
# 2       38887  2009-10-24   378.90    28.46            3           3
# 3       45860  2012-12-08    69.97    24.25            4           4
# 4       53156  2012-10-03   186.93    56.44            5           5
# ..        ...         ...      ...      ...          ...         ...
# 355     23782  2010-10-01   169.75  -194.85          291         159
# 356     14662  2011-11-16  5139.88  1275.67          203         301
# 357     51879  2010-08-24  1382.31   372.26           50         302
# 358     55846  2009-07-20   221.05   -66.38          184         102
# 359     12420  2010-12-26     5.73    -1.84          294         303
#
# [360 rows x 6 columns]

# %%
# Data Cleaning

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_ID     360 non-null    int64
#  1   order_date   360 non-null    str
#  2   sales        360 non-null    float64
#  3   profit       360 non-null    float64
#  4   customer_id  360 non-null    int64
#  5   product_id   360 non-null    int64
# dtypes: float64(2), int64(3), str(1)
# memory usage: 17.0 KB

# %%
products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    302 non-null    int64
#  1   product_name  302 non-null    str
#  2   category      301 non-null    str
# dtypes: int64(1), str(2)
# memory usage: 7.2 KB

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 294 entries, 0 to 293
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    294 non-null    int64
#  1   customer_name  294 non-null    str
#  2   region         294 non-null    str
# dtypes: int64(1), str(2)
# memory usage: 7.0 KB

# %%
sales.describe().round()
# Out:
#        order_ID    sales   profit  customer_id  product_id
# count     360.0    360.0    360.0        360.0       360.0
# mean    30549.0   2093.0    329.0        132.0       143.0
# std     17082.0   5841.0   1792.0         84.0        88.0
# min       293.0      6.0  -2661.0          1.0         1.0
# 25%     14521.0    151.0    -59.0         56.0        63.0
# 50%     31459.0    515.0      7.0        128.0       138.0
# 75%     45411.0   1740.0    232.0        202.0       219.0
# max     59651.0  89061.0  27221.0        294.0       303.0

# %%
products.describe().round()
# Out:
#        product_id
# count       302.0
# mean        152.0
# std          88.0
# min           1.0
# 25%          76.0
# 50%         152.0
# 75%         228.0
# max         303.0

# %%
customers.describe().round()
# Out:
#        customer_id
# count        294.0
# mean         148.0
# std           85.0
# min            1.0
# 25%           74.0
# 50%          148.0
# 75%          221.0
# max          294.0

# %%
# Null Values

# %%
sales.isnull().sum()
# Out:
# order_ID       0
# order_date     0
# sales          0
# profit         0
# customer_id    0
# product_id     0
# dtype: int64

# %%
sales.shape
# Out:
# (360, 6)

# %%
products.isnull().sum()
# Out:
# product_id      0
# product_name    0
# category        1
# dtype: int64

# %%
products.shape
# Out:
# (302, 3)

# %%
customers.isnull().sum()
# Out:
# customer_id      0
# customer_name    0
# region           0
# dtype: int64

# %%
customers.shape
# Out:
# (294, 3)

# %%
# Duplicate values

# %%
sales[sales.duplicated()].shape
# Out:
# (0, 6)

# %%
products[products.duplicated()].shape
# Out:
# (0, 3)

# %%
customers[customers.duplicated()].shape
# Out:
# (0, 3)

# %%
sales['order_ID'].value_counts().head(10)
# Out:
# order_ID
# 46624    2
# 59270    2
# 46885    2
# 47872    2
# 53060    2
# 43207    2
# 9091     1
# 36355    1
# 38887    1
# 45860    1
# Name: count, dtype: int64

# %%
sales[sales['order_ID'] == '45860']
# Out:
# Empty DataFrame
# Columns: [order_ID, order_date, sales, profit, customer_id, product_id]
# Index: []

# %%
for col in products.columns:
    if products[col].nunique() < 20:
        print(products[col].value_counts())
        print('-' == 50)
# Out:
# category
# Office Supplies    168
# Technology          75
# Furniture           58
# Name: count, dtype: int64
# False

# %%
for col in customers.columns:
    if customers[col].nunique() < 20:
        print(customers[col].value_counts())
        print('-' == 50)
# Out:
# region
# West                     70
# Ontario                  63
# Prarie                   58
# Atlantic                 41
# Quebec                   28
# Yukon                    17
# Northwest Territories    13
# Nunavut                   4
# Name: count, dtype: int64
# False

# %%
products.dropna(inplace=True)

# %%
products.isnull().sum()
# Out:
# product_id      0
# product_name    0
# category        0
# dtype: int64

# %%
# Merge / Join

# %%
df = sales.merge(customers, on="customer_id") \
          .merge(products, on="product_id")

df
# Out:
#      order_ID  order_date    sales   profit  customer_id  product_id  \
# 0        9091  2010-11-11   605.77   129.33            1           1
# 1       36355  2009-02-12   129.50    65.49            2           2
# 2       38887  2009-10-24   378.90    28.46            3           3
# 3       45860  2012-12-08    69.97    24.25            4           4
# 4       53156  2012-10-03   186.93    56.44            5           5
# ..        ...         ...      ...      ...          ...         ...
# 352     23782  2010-10-01   169.75  -194.85          291         159
# 353     14662  2011-11-16  5139.88  1275.67          203         301
# 354     51879  2010-08-24  1382.31   372.26           50         302
# 355     55846  2009-07-20   221.05   -66.38          184         102
# 356     12420  2010-12-26     5.73    -1.84          294         303
#
#           customer_name                 region  \
# 0             Adam Hart                  Yukon
# 1            Anne Pryor                 Quebec
# 2            Trudy Bell                   West
# 3        Matthew Clasen                 Prarie
# 4           Bryan Davis  Northwest Territories
# ..                  ...                    ...
# 352  Justin MacKendrick                 Quebec
# 353          Karl Brown               Atlantic
# 354      Monica Federle  Northwest Territories
# 355      Cari MacIntyre                Ontario
# 356          Joel Eaton                 Prarie
#
#                                           product_name         category
# 0                           Nu-Dell Leatherette Frames        Furniture
# 1                    Seth Thomas 8 1/2 Cubicle Clock""        Furniture
# 2    Acco Recycled 2 Capacity Laser Printer Hanging...  Office Supplies
# 3                   Wirebound Message Book, 4 per Page  Office Supplies
# 4                                            Avery 491  Office Supplies
# ..                                                 ...              ...
# 352                        Tennsco Commercial Shelving  Office Supplies
# 353                                                M70       Technology
# 354  Howard Miller 11-1/2 Diameter Ridgewood Wall C...        Furniture
# 355        Wilson Jones Hanging View Binder, White, 1"  Office Supplies
# 356                Rediform S.O.S. Phone Message Books  Office Supplies
#
# [357 rows x 10 columns]

# %%
# Merged Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 358 entries, 0 to 357
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_ID       358 non-null    int64
#  1   order_date     358 non-null    str
#  2   sales          358 non-null    float64
#  3   profit         358 non-null    float64
#  4   customer_id    358 non-null    int64
#  5   product_id     358 non-null    int64
#  6   customer_name  358 non-null    str
#  7   region         358 non-null    str
#  8   product_name   358 non-null    str
#  9   category       357 non-null    str
# dtypes: float64(2), int64(3), str(5)
# memory usage: 28.1 KB

# %%
df.isnull().sum()
# Out:
# order_ID         0
# order_date       0
# sales            0
# profit           0
# customer_id      0
# product_id       0
# customer_name    0
# region           0
# product_name     0
# category         0
# dtype: int64

# %%
df.shape
# Out:
# (357, 10)

# %%
df[df.duplicated()].shape
# Out:
# (0, 10)

# %%
df['order_ID'].value_counts().head(10)
# Out:
# order_ID
# 46624    2
# 59270    2
# 46885    2
# 47872    2
# 43207    2
# 9091     1
# 36355    1
# 38887    1
# 45860    1
# 53156    1
# Name: count, dtype: int64

# %%
df[df['order_ID'] == '46624']
# Out:
# Empty DataFrame
# Columns: [order_ID, order_date, sales, profit, customer_id, product_id, customer_name, region, product_name, category]
# Index: []

# %%
# Unique Values

# %%
df['category'].unique()
# Out:
# <StringArray>
# ['Furniture', 'Office Supplies', 'Technology']
# Length: 3, dtype: str

# %%
df['region'].unique()
# Out:
# <StringArray>
# [                'Yukon',                'Quebec',                  'West',
#                 'Prarie', 'Northwest Territories',               'Ontario',
#               'Atlantic',               'Nunavut']
# Length: 8, dtype: str

# %%
for col in df.columns:
    if df[col].nunique() < 20:
        print(df[col].value_counts())
        print('-' == 50)
# Out:
# region
# Ontario                  84
# West                     77
# Prarie                   73
# Atlantic                 47
# Quebec                   36
# Yukon                    23
# Northwest Territories    13
# Nunavut                   4
# Name: count, dtype: int64
# False
# category
# Office Supplies    203
# Technology          90
# Furniture           64
# Name: count, dtype: int64
# False

# %%
# Remove null values

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# order_ID         0
# order_date       0
# sales            0
# profit           0
# customer_id      0
# product_id       0
# customer_name    0
# region           0
# product_name     0
# category         0
# dtype: int64

# %%
# Format conversion

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_ID       357 non-null    int64
#  1   order_date     357 non-null    datetime64[us]
#  2   sales          357 non-null    float64
#  3   profit         357 non-null    float64
#  4   customer_id    357 non-null    int64
#  5   product_id     357 non-null    int64
#  6   customer_name  357 non-null    str
#  7   region         357 non-null    str
#  8   product_name   357 non-null    str
#  9   category       357 non-null    str
# dtypes: datetime64[us](1), float64(2), int64(3), str(4)
# memory usage: 28.0 KB

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
df['month'] = df['order_date'].dt.month

# %%
df['month']
# Out:
# 0      11
# 1       2
# 2      10
# 3      12
# 4      10
#        ..
# 352    10
# 353    11
# 354     8
# 355     7
# 356    12
# Name: month, Length: 357, dtype: int32

# %%
df
# Out:
#      order_ID order_date    sales   profit  customer_id  product_id  \
# 0        9091 2010-11-11   605.77   129.33            1           1
# 1       36355 2009-02-12   129.50    65.49            2           2
# 2       38887 2009-10-24   378.90    28.46            3           3
# 3       45860 2012-12-08    69.97    24.25            4           4
# 4       53156 2012-10-03   186.93    56.44            5           5
# ..        ...        ...      ...      ...          ...         ...
# 352     23782 2010-10-01   169.75  -194.85          291         159
# 353     14662 2011-11-16  5139.88  1275.67          203         301
# 354     51879 2010-08-24  1382.31   372.26           50         302
# 355     55846 2009-07-20   221.05   -66.38          184         102
# 356     12420 2010-12-26     5.73    -1.84          294         303
#
#           customer_name                 region  \
# 0             Adam Hart                  Yukon
# 1            Anne Pryor                 Quebec
# 2            Trudy Bell                   West
# 3        Matthew Clasen                 Prarie
# 4           Bryan Davis  Northwest Territories
# ..                  ...                    ...
# 352  Justin MacKendrick                 Quebec
# 353          Karl Brown               Atlantic
# 354      Monica Federle  Northwest Territories
# 355      Cari MacIntyre                Ontario
# 356          Joel Eaton                 Prarie
#
#                                           product_name         category  month
# 0                           Nu-Dell Leatherette Frames        Furniture     11
# 1                    Seth Thomas 8 1/2 Cubicle Clock""        Furniture      2
# 2    Acco Recycled 2 Capacity Laser Printer Hanging...  Office Supplies     10
# 3                   Wirebound Message Book, 4 per Page  Office Supplies     12
# 4                                            Avery 491  Office Supplies     10
# ..                                                 ...              ...    ...
# 352                        Tennsco Commercial Shelving  Office Supplies     10
# 353                                                M70       Technology     11
# 354  Howard Miller 11-1/2 Diameter Ridgewood Wall C...        Furniture      8
# 355        Wilson Jones Hanging View Binder, White, 1"  Office Supplies      7
# 356                Rediform S.O.S. Phone Message Books  Office Supplies     12
#
# [357 rows x 11 columns]

# %%
# Data Analysis

# %%
# Sales by Region

# %%
import matplotlib.pyplot as plt
df.groupby('region')['sales'].sum().plot(kind='bar')
plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.savefig("Sales by Region.png")
plt.show()

# %%
# Profit by Category

# %%
profit_category = df.groupby('category')['profit'].sum()
profit_category.plot(kind='pie', autopct = '%0.f%%')
plt.title("Profit by Category")
plt.savefig("Profit by Category.png")
plt.show()

# %%
# Monthly Sales Trend

# %%
monthly_sales = df.groupby('month')['sales'].sum()
monthly_sales.plot(kind='line', color = 'red', marker='o')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.savefig("Monthly Sales Trend.png")
plt.show()

# %%
# Top 4 Products

# %%
plt.figure(figsize = (4, 3))
top_products = df.groupby('product_name')['sales'].sum().sort_values(ascending=False).head(4)

top_products.plot(kind='bar', color = 'skyblue')
plt.title("Top 4 Products")
plt.xlabel("Product")
plt.ylabel("Sales")
plt.show()

# %%
# Top 5 Customers

# %%
plt.figure(figsize = (4, 3))
top_customers = df.groupby('customer_name')['sales'].sum().sort_values(ascending=False).head(5)

top_customers.plot(kind='bar', color = 'pink')
plt.title("Top 5 Customers")
plt.xlabel("Customer")
plt.ylabel("Sales")
plt.show()
